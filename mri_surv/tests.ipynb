# %%
from statistics.survival_analysis import get_raw_kmf_by_group_full, load_metadata_mlp_pivot

mlp = load_metadata_mlp_pivot()
get_raw_kmf_by_group_full(mlp)
# Out:
# /home/mfromano/anaconda3/envs/mri-pet/lib/python3.7/site-packages/outdated/utils.py:18: OutdatedPackageWarning: The package outdated is out of date. Your version is 0.2.0, the latest is 0.2.2.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   **kwargs
# /home/mfromano/anaconda3/envs/mri-pet/lib/python3.7/site-packages/outdated/utils.py:18: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.5.0, the latest is 0.5.2.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   **kwargs
#     At Risk  Times  Observed  Censored Subtype Dataset
# 0       139      0      15.0       9.0       0    ADNI
# 1       115     12      21.0      21.0       0    ADNI
# 2        73     24      16.0       5.0       0    ADNI
# 3        52     36       6.0      10.0       0    ADNI
# 4        36     48       6.0      11.0       0    ADNI
# ..      ...    ...       ...       ...     ...     ...
# ...

# %%
from statistics.shap_viz.shap_stats_cnn import bootstrap_pvals

bootstrap_pvals('cnn')
# Out:
# /home/mfromano/anaconda3/envs/mri-pet/lib/python3.7/site-packages/outdated/utils.py:18: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.5.0, the latest is 0.5.2.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   **kwargs
# /home/mfromano/anaconda3/envs/mri-pet/lib/python3.7/site-packages/outdated/utils.py:18: OutdatedPackageWarning: The package outdated is out of date. Your version is 0.2.0, the latest is 0.2.2.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   **kwargs
#   0%|          | 0/508 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_19719/1669561794.py in <module>
#       1 from statistics.shap_viz.shap_brains_cnn import mask_brain_all_lobe_mn
#       2
# ----> 3 mask_brain_all_lobe_mn(True)
#
# ...

# %%
from statistics.survival_analysis import *

mlp_pivot = load_metadata_mlp_pivot()
results = compare_surv_logrank(mlp_pivot)
# Out:
# /home/mfromano/anaconda3/envs/mri-pet/lib/python3.7/site-packages/outdated/utils.py:18: OutdatedPackageWarning: The package outdated is out of date. Your version is 0.2.0, the latest is 0.2.2.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   **kwargs
# /home/mfromano/anaconda3/envs/mri-pet/lib/python3.7/site-packages/outdated/utils.py:18: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.5.0, the latest is 0.5.2.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   **kwargs
# /home/mfromano/anaconda3/envs/mri-pet/lib/python3.7/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# ---------------------------------------------------------------------------
# ...

# %%
from statistics.shap_viz.shap_stats_cnn import pairwise_pvals_abs_all

pairwise_pvals_abs_all()
# Out:
# /home/mfromano/anaconda3/envs/mri-pet/lib/python3.7/site-packages/outdated/utils.py:18: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.5.0, the latest is 0.5.3.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   **kwargs
# /home/mfromano/anaconda3/envs/mri-pet/lib/python3.7/site-packages/outdated/utils.py:18: OutdatedPackageWarning: The package outdated is out of date. Your version is 0.2.0, the latest is 0.2.2.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   **kwargs
# ...
# H, ('TL-O', 'Ins'): 134, 134
# H, ('TL-O', 'OL'): 134, 134
# H, ('TL-O', 'TL-M'): 134, 134
# H, ('TL-O', 'BG'): 134, 134
# H, ('TL-O', 'FL'): 134, 134
# H, ('TL-O', 'PL'): 134, 134
# H, ('TL-O', 'Cing'): 134, 134
# H, ('TL-O', 'SC'): 134, 134
# H, ('Ins', 'OL'): 134, 134
# H, ('Ins', 'TL-M'): 134, 134
# H, ('Ins', 'BG'): 134, 134
# H, ('Ins', 'FL'): 134, 134
# H, ('Ins', 'PL'): 134, 134
# H, ('Ins', 'Cing'): 134, 134
# ...

# %%
from statistics.demographic_statistics import *
# Out:
# /home/mfromano/anaconda3/envs/mri-pet/lib/python3.7/site-packages/outdated/utils.py:18: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.5.0, the latest is 0.5.3.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   **kwargs
# /home/mfromano/anaconda3/envs/mri-pet/lib/python3.7/site-packages/outdated/utils.py:18: OutdatedPackageWarning: The package outdated is out of date. Your version is 0.2.0, the latest is 0.2.2.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   **kwargs

# %%
tats = TrainAndTestStats()

# %%
from statistics.radiology_analysis import radiology_analysis

radiology_analysis.main()
# Out:
# /home/mfromano/anaconda3/envs/mri-pet/lib/python3.7/site-packages/outdated/utils.py:18: OutdatedPackageWarning: The package outdated is out of date. Your version is 0.2.0, the latest is 0.2.2.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   **kwargs
# /home/mfromano/anaconda3/envs/mri-pet/lib/python3.7/site-packages/outdated/utils.py:18: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.5.0, the latest is 0.5.3.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   **kwargs
# Region
# Cingulate           (179.5, 0.010290245458960763, 24, 24)
# Frontal            (144.5, 0.0013670693657757474, 24, 24)
# Insula               (209.5, 0.05027467020979471, 24, 24)
# Mesial Temporal       (177.5, 0.0113480512729697, 24, 24)
# Occipital           (155.5, 0.002423296065411364, 24, 24)
# Other Temporal      (144.5, 0.001392429275680925, 24, 24)
# Parietal           (147.0, 0.0018073622715991209, 24, 24)
# ...
