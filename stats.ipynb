# %%
# mri-pet environment
from statistics import demographic_statistics

demographic_statistics.main()
# Out:
# [0, 12, 24, 36, 48, 60, 72, 84, 96, inf]
#           removed  observed  censored  entrance  at_risk
# event_at
# 0.0            26         0        26       544      544
# 6.0            33        24         9         0      518
# 12.0          111        33        78         0      485
# 18.0            5         5         0         0      374
# 24.0           81        35        46         0      369
# 36.0           61        20        41         0      288
# 48.0           69        14        55         0      227
# 60.0           41         4        37         0      158
# 72.0           25         8        17         0      117
# 84.0           48         6        42         0       92
# 96.0           33         4        29         0       44
# 108.0          11         1        10         0       11
#             removed  observed  censored  entrance  at_risk
# event_at
# 0.000000        108         0       108       508      508
# ...

# %%
# mri-pet
from statistics import survival_analysis

survival_analysis.main()

# %%
# mri-pet

from statistics import brain_visualization

brain_visualization.main()
# Out:
# /home/mfromano/Research/mri-surv-dev/mri_surv/statistics/brain_visualization.py:319: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.savefig(f_name, dpi=300)

# %%
# mri-surv
from statistics.radiology_analysis import radiology_analysis

radiology_analysis.main()
# Out:
# /home/mfromano/anaconda3/envs/mri-pet/lib/python3.7/site-packages/outdated/utils.py:18: OutdatedPackageWarning: The package outdated is out of date. Your version is 0.2.0, the latest is 0.2.2.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   **kwargs
# /home/mfromano/anaconda3/envs/mri-pet/lib/python3.7/site-packages/outdated/utils.py:18: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.5.0, the latest is 0.5.3.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   **kwargs
# Region
# Cingulate           (396.5, 0.020580490917921527, 24, 24)
# Frontal             (431.5, 0.002734138731551495, 24, 24)
# Insula               (366.5, 0.10054934041958942, 24, 24)
# Mesial Temporal       (398.5, 0.0226961025459394, 24, 24)
# Occipital           (420.5, 0.004846592130822728, 24, 24)
# Other Temporal       (431.5, 0.00278485855136185, 24, 24)
# Parietal           (429.0, 0.0036147245431982417, 24, 24)
# ...

# %%
# mri-surv
from statistics.pathology import pathology_revision

pathology_revision.main()

# %%
# torch-env
from statistics.shap_viz.shap_stats_cnn import pairwise_pvals_abs_all

pairwise_pvals_abs_all()

# %%
# torch-env

from simple_mlps import mlp_wrappers

mlp_wrappers.main()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_11255/892149875.py in <module>
#       1 # torch-env
#       2
# ----> 3 from simple_mlps import mlp_wrappers
#       4
#       5 mlp_wrappers.main()
#
# ~/Research/mri-surv-dev/mri_surv/simple_mlps/mlp_wrappers.py in <module>
#       1 from copy import deepcopy
#       2 import numpy as np
# ----> 3 import torch
#       4 import os, sys
#       5 import json
#
# ModuleNotFoundError: No module named 'torch'

# %%
# torch-env
from weibull_mlp import run

run.train_weibull()

# %%
# torch-env
from statistics import stats_surv_with_gmv_csf_mlp

# %%
# r
"Rscript statistics/gray_matter_vol.r"

# %%
# torch-env
from statistics.shap_viz.shap_stats_cnn import bootstrap_pvals

bootstrap_pvals('cnn')
